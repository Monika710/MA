# %%
# import the required module
from utils.utils import generate_results_csv
from utils.utils import create_directory
from utils.utils import read_dataset
from utils.utils import get_func_length
from utils.utils import transform_to_same_length
from utils.utils import transform_mts_to_ucr_format
from utils.utils import visualize_filter
from utils.utils import viz_for_survey_paper
from utils.utils import viz_cam

# %%
# import the required module
import os
import numpy as np
import pandas as pd
import sys
import sklearn
import utils
import classifiers
import datetime
import optuna

from utils.constants import CLASSIFIERS
from utils.constants import ARCHIVE_NAMES
from utils.constants import ITERATIONS
from utils.utils import read_all_datasets
from sklearn.metrics import r2_score

# %%
# Definition of fit function
def fit_classifier():
    x_train = datasets_dict[dataset_name][0]
    y_train = datasets_dict[dataset_name][1]
    x_test = datasets_dict[dataset_name][2]
    y_test = datasets_dict[dataset_name][3]

    nb_classes = len(np.unique(np.concatenate((y_train, y_test), axis=0)))

    # transform the labels from integers to one hot vectors
    enc = sklearn.preprocessing.OneHotEncoder(categories='auto')
    enc.fit(np.concatenate((y_train, y_test), axis=0).reshape(-1, 1))
    y_train = enc.transform(y_train.reshape(-1, 1)).toarray()
    y_test = enc.transform(y_test.reshape(-1, 1)).toarray()

    # save orignal y because later we will use binary
    y_true = np.argmax(y_test, axis=1)

    if len(x_train.shape) == 2:  # if univariate
        # add a dimension to make it multivariate with one dimension 
        x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
        x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

    input_shape = x_train.shape[1:] 
    print(input_shape)
    classifier = create_classifier(classifier_name, input_shape, nb_classes, output_directory)

    classifier.fit(x_train, y_train, x_test, y_test, y_true)

# %%
# Definition of classifier 
def create_classifier(classifier_name, input_shape, nb_classes, output_directory, verbose=False):
    if classifier_name == 'fcn':
        from classifiers import fcn
        return fcn.Classifier_FCN(output_directory, input_shape, nb_classes, verbose)
    if classifier_name == 'resnet':
        from classifiers import resnet
        return resnet.Classifier_RESNET(output_directory, input_shape, nb_classes, verbose)
        return inception.Classifier_INCEPTION(output_directory, input_shape, nb_classes, verbose)
    if classifier_name == 'fcn_model_10':
        from classifiers import fcn_model_10
        return fcn_model_10.Classifier_FCN_MODEL_10(output_directory, input_shape, nb_classes, verbose)    
    if classifier_name == 'fcn_model_7':
        from classifiers import fcn_model_7
        return fcn_model_7.Classifier_FCN_MODEL_7(output_directory, input_shape, nb_classes, verbose)  
    if classifier_name == 'fcn_model_11':
        from classifiers import fcn_model_11
        return fcn_model_11.Classifier_FCN_MODEL_11(output_directory, input_shape, nb_classes, verbose)  
    if classifier_name == 'fcn_model_8':
        from classifiers import fcn_model_8
        return fcn_model_8.Classifier_FCN_MODEL_8(output_directory, input_shape, nb_classes, verbose)  
    if classifier_name == 'fcn_model_9':
        from classifiers import fcn_model_9
        return fcn_model_9.Classifier_FCN_MODEL_9(output_directory, input_shape, nb_classes, verbose)  
    if classifier_name == 'fcn_model_5':
        from classifiers import fcn_model_5
        return fcn_model_5.Classifier_FCN_MODEL_5(output_directory, input_shape, nb_classes, verbose)  
    if classifier_name == 'fcn_model_3':
        from classifiers import fcn_model_3
        return fcn_model_3.Classifier_FCN_MODEL_3(output_directory, input_shape, nb_classes, verbose)  
    if classifier_name == 'fcn_model_20':
        from classifiers import fcn_model_20
        return fcn_model_20.Classifier_FCN_MODEL_20(output_directory, input_shape, nb_classes, verbose)  
    if classifier_name == 'fcn_model_21':
        from classifiers import fcn_model_21
        return fcn_model_21.Classifier_FCN_MODEL_21(output_directory, input_shape, nb_classes, verbose)

# %%
# change this directory for your machine
# it should contain the archive folder containing both univariate and multivariate archives
# import our dataset
root_dir = 'D:/FH_Dortmund/Projekt/Projektarbeit_2/time_series/dl-4-tsc-master/dataset'
# root_dir = 'D:/FH_Dortmund/Projekt/Projektarbeit_2/time_series/dl-4-tsc-master/dataset/archives/UCRArchive_2018/Computers/'

# %%
# original model

starttime = datetime.datetime.now()

archive_name = "UCRArchive_2018"
dataset_name = 'DistalPhalanxOutlineAgeGroup'
classifier_name = 'fcn_model_21'
# classifier_name = 'resnet'
itr = '0'
# iter = the folder number
iter = 25

# nb of random runs for random initializations
ITERATIONS = 5 
datasets_dict = read_all_datasets(root_dir, archive_name)



print('\t\titer', iter)
trr = ''
if iter != 0:
    trr = '_itr_' + str(iter)

    tmp_output_directory = root_dir + '/results/' + classifier_name + '/' + archive_name + trr + '/'

    print('\t\t\tdataset_name: ', dataset_name)

    output_directory = tmp_output_directory + dataset_name + '/'

    create_directory(output_directory)


    
    fit_classifier()

    print('\t\t\t\tDONE')

        # the creation of this directory means
    create_directory(output_directory + '/DONE')

else:
    print('iter = ', iter)
    
endtime = datetime.datetime.now()

print (endtime-starttime)
# Out:
# 		iter 25
# 			dataset_name:  DistalPhalanxOutlineAgeGroup
# (80, 1)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 80, 1)]           0
#
#  conv1d (Conv1D)             (None, 80, 64)            640
#
#  batch_normalization (BatchN  (None, 80, 64)           256
#  ormalization)
#
#  activation (Activation)     (None, 80, 64)            0
#
#  dropout (Dropout)           (None, 80, 64)            0
#
#  conv1d_1 (Conv1D)           (None, 80, 128)           114816
#
#  batch_normalization_1 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 80, 128)           0
#
#  dropout_1 (Dropout)         (None, 80, 128)           0
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
# ...

# %%
starttime = datetime.datetime.now()
archive_name = "UCRArchive_2018"
classifier_name = 'fcn'
itr = '0'
# iter = the folder number
iter = 1

# nb of random runs for random initializations
ITERATIONS = 5 
datasets_dict = read_all_datasets(root_dir, archive_name)

print('\t\titer', iter)
trr = ''
if iter != 0:
    trr = '_itr_' + str(iter)

    for dataset_name in utils.constants.dataset_names_for_archive[archive_name]:
        print('\t\t\tdataset_name: ', dataset_name)
    
        tmp_output_directory = root_dir + '/results/' + classifier_name + '/' + archive_name + trr + '/'

        output_directory = tmp_output_directory + dataset_name + '/'

        create_directory(output_directory)

        fit_classifier()

        print('\t\t\t\tDONE')

        # the creation of this directory means
        create_directory(output_directory + '/DONE')

else:
    print('iter = ', iter)
    
endtime = datetime.datetime.now()

print (endtime-starttime)
# Out:
# 		iter 1
# 			dataset_name:  HouseTwenty
# (2000, 1)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 2000, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 2000, 128)         1152
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2000, 128)         512
# _________________________________________________________________
# activation (Activation)      (None, 2000, 128)         0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2000, 256)         164096
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2000, 256)         1024
# _________________________________________________________________
# ...
